# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pymongo
import seaborn as sns

# %%
Client=pymongo.MongoClient("mongodb+srv://ragult:Ragul29072001@cluster0.dxjzum0.mongodb.net/")

# %%
Client.list_database_names()
# Out:
# ['airbnbanalysis',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
db=Client["sample_airbnb"]
db.list_collection_names()
# Out:
# ['listingsAndReviews']

# %%
db = Client.sample_airbnb
Collection=db.listingsAndReviews

# %%
data=[]
for i in Collection.find():
    data.append(i)
#data[0]

# %%
pd.set_option('display.max_columns', 500)

# %%
airbnb = pd.DataFrame(data)
airbnb
# Out:
#            _id                            listing_url  \
# 0     10057826  https://www.airbnb.com/rooms/10057826
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10059872  https://www.airbnb.com/rooms/10059872
# 4     10006546  https://www.airbnb.com/rooms/10006546
# ...        ...                                    ...
# 5550   9846545   https://www.airbnb.com/rooms/9846545
# 5551   9887054   https://www.airbnb.com/rooms/9887054
# 5552   9917859   https://www.airbnb.com/rooms/9917859
# 5553   9993190   https://www.airbnb.com/rooms/9993190
# 5554   9969335   https://www.airbnb.com/rooms/9969335
#
#                                                    name  \
# 0                                     Deluxe Loft Suite
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                    Soho Cozy, Spacious and Convenient
# ...

# %%
airbnb.to_csv('airbnb.csv', index=False)

# %%
Airbnb = pd.read_csv('airbnb.csv')
Airbnb
# Out:
#            _id                            listing_url  \
# 0     10057826  https://www.airbnb.com/rooms/10057826
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10059872  https://www.airbnb.com/rooms/10059872
# 4     10006546  https://www.airbnb.com/rooms/10006546
# ...        ...                                    ...
# 5550   9846545   https://www.airbnb.com/rooms/9846545
# 5551   9887054   https://www.airbnb.com/rooms/9887054
# 5552   9917859   https://www.airbnb.com/rooms/9917859
# 5553   9993190   https://www.airbnb.com/rooms/9993190
# 5554   9969335   https://www.airbnb.com/rooms/9969335
#
#                                                    name  \
# 0                                     Deluxe Loft Suite
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                    Soho Cozy, Spacious and Convenient
# ...

# %%
Airbnb.drop(columns=["_id","address","host","availability",'review_scores','amenities','images','reviews','listing_url','summary','first_review'],inplace= True)
Airbnb.drop(columns=['last_review','interaction','cleaning_fee','space','description','neighborhood_overview','notes','transit'], inplace=True)
Airbnb.drop(columns=['house_rules','access','last_scraped','calendar_last_scraped','security_deposit','weekly_price','monthly_price','reviews_per_month'], inplace=True)

# %%
Airbnb.isnull().sum()
# Out:
# name                    8
# property_type           0
# room_type               0
# bed_type                0
# minimum_nights          0
# maximum_nights          0
# cancellation_policy     0
# accommodates            0
# bedrooms                5
# beds                   13
# number_of_reviews       0
# bathrooms              10
# price                   0
# extra_people            0
# guests_included         0
# dtype: int64

# %%
Airbnb.shape
# Out:
# (5555, 15)

# %%
Airbnb.columns
# Out:
# Index(['name', 'property_type', 'room_type', 'bed_type', 'minimum_nights',
#        'maximum_nights', 'cancellation_policy', 'accommodates', 'bedrooms',
#        'beds', 'number_of_reviews', 'bathrooms', 'price', 'extra_people',
#        'guests_included'],
#       dtype='object')

# %%
Airbnb["name"].fillna(Airbnb["name"].mode()[0], inplace=True)
Airbnb["bedrooms"].fillna(Airbnb["bedrooms"].mean(),inplace=True)
Airbnb["beds"].fillna(Airbnb["beds"].mean(),inplace=True)
Airbnb["bathrooms"].fillna(Airbnb["bathrooms"].mean(),inplace=True)
Airbnb["bedrooms"].fillna(Airbnb["bedrooms"].mean(),inplace=True)

# %%
Airbnb.dtypes
# Out:
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights           int64
# maximum_nights           int64
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms              float64
# price                  float64
# extra_people           float64
# guests_included          int64
# dtype: object

# %%
Airbnb.isnull().sum()
# Out:
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# extra_people           0
# guests_included        0
# dtype: int64

# %%
Airbnb['bedrooms'] = Airbnb['bedrooms'].astype(int)
Airbnb['beds'] = Airbnb['beds'].astype(int)
Airbnb['bathrooms']=Airbnb["bathrooms"].astype(int)
Airbnb["extra_people"]=Airbnb["extra_people"].astype(int)
Airbnb["guests_included"]=Airbnb["guests_included"].astype(int)

# %%
Airbnb.dtypes
# Out:
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights           int64
# maximum_nights           int64
# cancellation_policy     object
# accommodates             int64
# bedrooms                 int32
# beds                     int32
# number_of_reviews        int64
# bathrooms                int32
# price                  float64
# extra_people             int32
# guests_included          int32
# dtype: object

# %%
Airbnb.describe()
# Out:
#        minimum_nights  maximum_nights  accommodates     bedrooms         beds  \
# count     5555.000000    5.555000e+03   5555.000000  5555.000000  5555.000000
# mean         5.564356    1.382776e+06      3.505851     1.411341     2.071287
# std         22.613861    5.256920e+07      2.297019     1.041547     1.617767
# min          1.000000    1.000000e+00      1.000000     0.000000     0.000000
# 25%          1.000000    5.900000e+01      2.000000     1.000000     1.000000
# 50%          2.000000    1.125000e+03      3.000000     1.000000     2.000000
# 75%          3.000000    1.125000e+03      4.000000     2.000000     3.000000
# max       1250.000000    2.147484e+09     16.000000    20.000000    25.000000
#
#        number_of_reviews    bathrooms         price  extra_people  \
# count        5555.000000  5555.000000   5555.000000   5555.000000
# mean           27.606481     1.258146    278.766157     22.791899
# std            49.798376     0.683651    842.215531     69.331511
# ...

# %%
Q1=Airbnb["minimum_nights"].quantile(0.25)
Q3=Airbnb["minimum_nights"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+(1.5*IQR)
LP=Q1-(1.5*IQR)
print(UP,LP)
# Out:
# 6.0 -2.0

# %%
Q1=Airbnb["maximum_nights"].quantile(0.25)
Q3=Airbnb["maximum_nights"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+1.5*IQR
LP=Q1-1.5*IQR
print(UP,LP)
# Out:
# 2724.0 -1540.0

# %%
Q1=Airbnb["accommodates"].quantile(0.25)
Q3=Airbnb["accommodates"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+1.5*IQR
LP=Q1-1.5*IQR
print(UP,LP)
# Out:
# 7.0 -1.0

# %%
Q1=Airbnb["bedrooms"].quantile(0.25)
Q3=Airbnb["bedrooms"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+1.5*IQR
LP=Q1-1.5*IQR
print(UP,LP)
# Out:
# 3.5 -0.5

# %%
Q1=Airbnb["beds"].quantile(0.25)
Q3=Airbnb["beds"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+1.5*IQR
LP=Q1-1.5*IQR
print(UP,LP)
# Out:
# 6.0 -2.0

# %%
Q1=Airbnb["number_of_reviews"].quantile(0.25)
Q3=Airbnb["number_of_reviews"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+1.5*IQR
LP=Q1-1.5*IQR
print(UP,LP)
# Out:
# 78.5 -45.5

# %%
Q1=Airbnb["bathrooms"].quantile(0.25)
Q3=Airbnb["bathrooms"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+1.5*IQR
LP=Q1-1.5*IQR
print(UP,LP)
# Out:
# 1.0 1.0

# %%
Q1=Airbnb["extra_people"].quantile(0.25)
Q3=Airbnb["extra_people"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+1.5*IQR
LP=Q1-1.5*IQR
print(UP,LP)
# Out:
# 50.0 -30.0

# %%
Q1=Airbnb["guests_included"].quantile(0.25)
Q3=Airbnb["guests_included"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+1.5*IQR
LP=Q1-1.5*IQR
print(UP,LP)
# Out:
# 3.5 -0.5

# %%
Airbnb["minimum_nights"]=Airbnb["minimum_nights"].clip(UP,LP)
Airbnb["maximum_nights"]=Airbnb["maximum_nights"].clip(UP,LP)
Airbnb["accommodates"]=Airbnb["accommodates"].clip(UP,LP)
Airbnb["bedrooms"]=Airbnb["bedrooms"].clip(UP,LP)
Airbnb["beds"]=Airbnb["beds"].clip(UP,LP)
Airbnb["number_of_reviews"]=Airbnb["number_of_reviews"].clip(UP,LP)
Airbnb["bathrooms"]=Airbnb["bathrooms"].clip(UP,LP)
Airbnb["extra_people"]=Airbnb["extra_people"].clip(UP,LP)
Airbnb["guests_included"]=Airbnb["guests_included"].clip(UP,LP)

# %%
Airbnb=pd.DataFrame(Airbnb)
Airbnb
# Out:
#                                                    name property_type  \
# 0                                     Deluxe Loft Suite     Apartment
# 1                          Horto flat with small garden     Apartment
# 2                      Ocean View Waikiki Marina w/prkg   Condominium
# 3                    Soho Cozy, Spacious and Convenient     Apartment
# 4                               Ribeira Charming Duplex         House
# ...                                                 ...           ...
# 5550             Cozy Private Room near Olympic MTR (A)     Apartment
# 5551                Quarry Bay fully furnished studio C     Apartment
# 5552                   StayIN Oporto Música - Apartment     Apartment
# 5553  Just Steps from the Ocean at Premier Platinum ...     Townhouse
# 5554                 Central, Modern, University, Metro     Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# ...

# %%
# airbnb.to_csv('airbnb.csv', index=False)

# %%
Df=pd.DataFrame(airbnb["address"])
Df
# Out:
#                                                 address
# 0     {'street': 'Brooklyn, NY, United States', 'sub...
# 1     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 2     {'street': 'Honolulu, HI, United States', 'sub...
# 3     {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 4     {'street': 'Porto, Porto, Portugal', 'suburb':...
# ...                                                 ...
# 5550  {'street': 'Hong Kong, Kowloon, Hong Kong', 's...
# 5551  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5552  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 5553  {'street': 'Lahaina, HI, United States', 'subu...
# 5554  {'street': 'Porto, Porto, Portugal', 'suburb':...
#
# [5555 rows x 1 columns]

# %%
Df.address[1].values()
# Out:
# dict_values(['Rio de Janeiro, Rio de Janeiro, Brazil', 'Jardim Botânico', 'Jardim Botânico', 'Rio De Janeiro', 'Brazil', 'BR', {'type': 'Point', 'coordinates': [-43.23074991429229, -22.966253551739655], 'is_location_exact': True}])

# %%
Address=pd.DataFrame(Df)

# %%
Address["street"]=Address["address"].apply(lambda x: x["street"])  
Address["suburb"]=Address["address"].apply(lambda x: x["suburb"])
Address["government_area"]=Address["address"].apply(lambda x: x["government_area"])
Address["market"]=Address["address"].apply(lambda x: x["market"])
Address["country"]=Address["address"].apply(lambda x: x["country"])
Address["country_code"]=Address["address"].apply(lambda x: x["country_code"])
Address["type"]=Address["address"].apply(lambda x: x["location"]["type"])
Address["Latitude"]=Address["address"].apply(lambda x: x["location"]["coordinates"][0])
Address["Longitude"]=Address["address"].apply(lambda x: x["location"]["coordinates"][1])
Address["is_location_exact"]=Address["address"].apply(lambda x: x["location"]["is_location_exact"])

# %%
Address
# Out:
#                                                 address  \
# 0     {'street': 'Brooklyn, NY, United States', 'sub...
# 1     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 2     {'street': 'Honolulu, HI, United States', 'sub...
# 3     {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 4     {'street': 'Porto, Porto, Portugal', 'suburb':...
# ...                                                 ...
# 5550  {'street': 'Hong Kong, Kowloon, Hong Kong', 's...
# 5551  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5552  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 5553  {'street': 'Lahaina, HI, United States', 'subu...
# 5554  {'street': 'Porto, Porto, Portugal', 'suburb':...
#
#                                       street                      suburb  \
# 0                Brooklyn, NY, United States                  Greenpoint
# 1     Rio de Janeiro, Rio de Janeiro, Brazil             Jardim Botânico
# ...

# %%
Address.drop(columns=["address"],inplace=True)

# %%
Address.isnull().sum()
# Out:
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# type                 0
# Latitude             0
# Longitude            0
# is_location_exact    0
# dtype: int64

# %%
address=pd.DataFrame(Address)
address
# Out:
#                                       street                      suburb  \
# 0                Brooklyn, NY, United States                  Greenpoint
# 1     Rio de Janeiro, Rio de Janeiro, Brazil             Jardim Botânico
# 2                Honolulu, HI, United States                       Oʻahu
# 3     Hong Kong, Hong Kong Island, Hong Kong  Central & Western District
# 4                     Porto, Porto, Portugal
# ...                                      ...                         ...
# 5550           Hong Kong, Kowloon, Hong Kong               Yau Tsim Mong
# 5551  Hong Kong, Hong Kong Island, Hong Kong                  Quarry Bay
# 5552                  Porto, Porto, Portugal
# 5553              Lahaina, HI, United States                     Lahaina
# 5554                  Porto, Porto, Portugal
#
#                                         government_area          market  \
# 0                                            Greenpoint        New York
# ...

# %%
# Custom function to fill NaN values in 'suburb' using 'market'
def fill_suburb_with_market(row):
    if pd.isna(row['suburb']):
        return row['market']
    else:
        return row['suburb']

# Apply the custom function to fill NaN values in 'suburb' column
address['suburb'] = address.apply(fill_suburb_with_market, axis=1)

# %%
missing_values = address[address['suburb'].isna()]

# Display the row(s) with missing value(s) in the 'suburb' column
print(missing_values)
# df.iloc[640]
# Out:
# Empty DataFrame
# Columns: [street, suburb, government_area, market, country, country_code, type, Latitude, Longitude, is_location_exact]
# Index: []

# %%
address.loc[640, 'suburb'] = "Copacabana"

# %%
missing_values = address[address['market'].isna()]

# Display the row(s) with missing value(s) in the 'suburb' column
print(missing_values)
# Out:
# Empty DataFrame
# Columns: [street, suburb, government_area, market, country, country_code, type, Latitude, Longitude, is_location_exact]
# Index: []

# %%
address.loc[ 576,"market"]="Québec"
address.loc[ 619,"market"]="Rio De Janeiro"
address.loc[ 640,"market"]="Porto"
address.loc[ 654,"market"]="Oahu"
address.loc[ 775,"market"]="Maui"
address.loc[ 791,"market"]="Istanbul"

# %%
address.dtypes
# Out:
# street                object
# suburb                object
# government_area       object
# market                object
# country               object
# country_code          object
# type                  object
# Latitude             float64
# Longitude            float64
# is_location_exact       bool
# dtype: object

# %%
# address["street"].isnull().sum()
address.isnull().sum()
# Out:
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# type                 0
# Latitude             0
# Longitude            0
# is_location_exact    0
# dtype: int64

# %%
address.duplicated().sum()
# Out:
# 0

# %%
address.describe()
# Out:
#           Latitude    Longitude
# count  5555.000000  5555.000000
# mean     -6.623240    22.061230
# std      90.525974    28.092112
# min    -159.678690   -34.088290
# 25%     -73.599530    20.724390
# 50%      -8.611420    40.727130
# 75%      29.019605    41.162755
# max     151.338980    45.665630

# %%
address['street'] = address['street'].str.split(',').str[0]
address['government_area'] = address['government_area'].str.split(',').str[0]

# %%
address.to_csv("address.csv", index=False)

# %%
address=pd.read_csv("address.csv")
address=pd.DataFrame(address)
address
# Out:
#               street                      suburb       government_area  \
# 0           Brooklyn                  Greenpoint            Greenpoint
# 1     Rio de Janeiro             Jardim Botânico       Jardim Botânico
# 2           Honolulu                       Oʻahu  Primary Urban Center
# 3          Hong Kong  Central & Western District     Central & Western
# 4              Porto                         NaN             Cedofeita
# ...              ...                         ...                   ...
# 5550       Hong Kong               Yau Tsim Mong         Yau Tsim Mong
# 5551       Hong Kong                  Quarry Bay               Eastern
# 5552           Porto                         NaN             Cedofeita
# 5553         Lahaina                     Lahaina               Lahaina
# 5554           Porto                         NaN             Cedofeita
#
#               market        country country_code   type   Latitude  Longitude  \
# ...

# %%
# airbnb.to_csv('airbnb.csv', index=False)

# %%
DF=pd.DataFrame(airbnb["host"])
DF
# Out:
#                                                    host
# 0     {'host_id': '47554473', 'host_url': 'https://w...
# 1     {'host_id': '1282196', 'host_url': 'https://ww...
# 2     {'host_id': '5448114', 'host_url': 'https://ww...
# 3     {'host_id': '51624384', 'host_url': 'https://w...
# 4     {'host_id': '51399391', 'host_url': 'https://w...
# ...                                                 ...
# 5550  {'host_id': '23134064', 'host_url': 'https://w...
# 5551  {'host_id': '31386255', 'host_url': 'https://w...
# 5552  {'host_id': '2296185', 'host_url': 'https://ww...
# 5553  {'host_id': '51013381', 'host_url': 'https://w...
# 5554  {'host_id': '2068687', 'host_url': 'https://ww...
#
# [5555 rows x 1 columns]

# %%
DF.host[1].values()
# Out:
# dict_values(['1282196', 'https://www.airbnb.com/users/show/1282196', 'Ynaie', 'Rio de Janeiro, State of Rio de Janeiro, Brazil', "I am an artist and traveling is a major part of my life. I love treating visitors the way I like to be treated when I´m abroad and I'm usually renting my flat while I'm away. I can recommend some cool parties and nights out as well as advise on some hidden secrets of Rio’s nature!", 'https://a0.muscache.com/im/pictures/9681e3cc-4af1-4046-b294-2881dffb4ff8.jpg?aki_policy=profile_small', 'https://a0.muscache.com/im/pictures/9681e3cc-4af1-4046-b294-2881dffb4ff8.jpg?aki_policy=profile_x_medium', 'Jardim Botânico', False, True, False, 1, 1, ['email', 'phone', 'facebook']])

# %%
DF.host[1].keys()
# Out:
# dict_keys(['host_id', 'host_url', 'host_name', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'host_listings_count', 'host_total_listings_count', 'host_verifications'])

# %%
host=pd.DataFrame(DF)
host['host_id'] = host['host'].apply(lambda x: x['host_id'])
host['host_url'] = host['host'].apply(lambda x: x['host_url'])
host['host_name'] = host['host'].apply(lambda x: x['host_name'])
host['host_location'] = host['host'].apply(lambda x: x['host_location'])
host['host_about'] = host['host'].apply(lambda x: x['host_about'])
host['host_response_time'] = host['host'].apply(lambda x: x.get('host_response_time','null'))
host['host_thumbnail_urlt'] = host['host'].apply(lambda x: x['host_thumbnail_url'])
host['host_picture_url'] = host['host'].apply(lambda x: x['host_picture_url'])
host['host_neighbourhood'] = host['host'].apply(lambda x: x['host_neighbourhood'])
host['host_response_rate'] = host['host'].apply(lambda x: x.get('host_response_rate',0))
host['host_is_superhost'] = host['host'].apply(lambda x: x['host_is_superhost'])
host['host_has_profile_pic'] = host['host'].apply(lambda x: x['host_has_profile_pic'])
host['host_identity_verified'] = host['host'].apply(lambda x: x['host_identity_verified'])
host['host_listings_count'] = host['host'].apply(lambda x: x['host_listings_count'])
host['host_total_listings_count'] = host['host'].apply(lambda x: x['host_total_listings_count'])
#host['host_verifications'] = host['host']['host_verifications'].apply(len)
host['host_verifications'] = host['host'].apply(lambda x: x['host_verifications'])
host['host_verifications'] = host['host_verifications'].apply(len)
# Drop the original 'host' column if not needed
host.drop(columns=['host'], inplace=True)

# %%
# host

# %%
host.isnull().sum()
# Out:
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_about                   0
# host_response_time           0
# host_thumbnail_urlt          0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
host.describe()
# Out:
#        host_response_rate  host_listings_count  host_total_listings_count  \
# count         5555.000000          5555.000000                5555.000000
# mean            69.851305            14.405761                  14.405761
# std             43.398098            65.848868                  65.848868
# min              0.000000             0.000000                   0.000000
# 25%              0.000000             1.000000                   1.000000
# 50%            100.000000             2.000000                   2.000000
# 75%            100.000000             6.000000                   6.000000
# max            100.000000          1198.000000                1198.000000
#
#        host_verifications
# count         5555.000000
# mean             4.968497
# std              2.176059
# min              1.000000
# 25%              3.000000
# 50%              5.000000
# 75%              7.000000
# max             12.000000

# %%
q3=host["host_verifications"].quantile(0.75)
q1=host["host_verifications"].quantile(0.25)
IQR=q3-q1
up=q3+(1.5*IQR)
lp=q1-(1.5*IQR)
print(up,lp)
# Out:
# 13.0 -3.0

# %%
host["host_verifications"] = host["host_verifications"].clip(up,lp)

# %%
q3=host["host_listings_count"].quantile(0.75)
q1=host["host_listings_count"].quantile(0.25)
IQR=q3-q1
up=q3+(1.5*IQR)
lp=q1-(1.5*IQR)
print(up,lp)
# Out:
# 13.5 -6.5

# %%
host["host_listings_count"]=host["host_listings_count"].clip(up,lp)

# %%
q3=host["host_total_listings_count"].quantile(0.75)
q1=host["host_total_listings_count"].quantile(0.25)
IQR=q3-q1
up=q3+(1.5*IQR)
lp=q1-(1.5*IQR)
print(up,lp)
# Out:
# 13.5 -6.5

# %%
host["host_total_listings_count"]=host["host_total_listings_count"].clip(up,lp)

# %%
host.describe()
# Out:
#        host_response_rate  host_listings_count  host_total_listings_count  \
# count         5555.000000          5555.000000                5555.000000
# mean            69.851305             4.203060                   4.203060
# std             43.398098             4.556895                   4.556895
# min              0.000000             0.000000                   0.000000
# 25%              0.000000             1.000000                   1.000000
# 50%            100.000000             2.000000                   2.000000
# 75%            100.000000             6.000000                   6.000000
# max            100.000000            13.500000                  13.500000
#
#        host_verifications
# count         5555.000000
# mean             4.968497
# std              2.176059
# min              1.000000
# 25%              3.000000
# 50%              5.000000
# 75%              7.000000
# max             12.000000

# %%
host["host_response_rate"].value_counts()
# Out:
# host_response_rate
# 100    2952
# 0      1485
# 90      133
# 98      109
# 99      104
#        ...
# 42        1
# 30        1
# 59        1
# 47        1
# 84        1
# Name: count, Length: 62, dtype: int64

# %%
host["host_response_rate"]=host["host_response_rate"].replace({"other":"12"})

# %%
host["host_response_rate"].value_counts()
# Out:
# host_response_rate
# 100    2952
# 0      1485
# 90      133
# 98      109
# 99      104
#        ...
# 42        1
# 30        1
# 59        1
# 47        1
# 84        1
# Name: count, Length: 62, dtype: int64

# %%
host.dtypes
# Out:
# host_id                       object
# host_url                      object
# host_name                     object
# host_location                 object
# host_about                    object
# host_response_time            object
# host_thumbnail_urlt           object
# host_picture_url              object
# host_neighbourhood            object
# host_response_rate             int64
# host_is_superhost               bool
# host_has_profile_pic            bool
# host_identity_verified          bool
# host_listings_count          float64
# host_total_listings_count    float64
# host_verifications             int64
# dtype: object

# %%
host.drop(columns=["host_id"],inplace=True)
host.drop(columns=["host_about","host_thumbnail_urlt","host_picture_url","host_neighbourhood"],inplace=True)

# %%
# host["host_neighbourhood"]=host["host_neighbourhood"].replace({"NAN":"NaN"})

# %%
# host["host_neighbourhood"].value_counts()

# %%
host.drop_duplicates(inplace=True)

# %%
# host.to_csv("host_main.csv", index=False)

# %%
host=pd.DataFrame(host)
host
# Out:
#                                         host_url       host_name  \
# 0     https://www.airbnb.com/users/show/47554473             Mae
# 1      https://www.airbnb.com/users/show/1282196           Ynaie
# 2      https://www.airbnb.com/users/show/5448114           David
# 3     https://www.airbnb.com/users/show/51624384        Giovanni
# 4     https://www.airbnb.com/users/show/51399391     Ana&Gonçalo
# ...                                          ...             ...
# 5547  https://www.airbnb.com/users/show/50141940           Paola
# 5548  https://www.airbnb.com/users/show/40540485          Miguel
# 5551  https://www.airbnb.com/users/show/31386255             Cat
# 5552   https://www.airbnb.com/users/show/2296185          Manuel
# 5554   https://www.airbnb.com/users/show/2068687  Daniel & Maria
#
#                                         host_location  host_response_time  \
# 0                                                  US  within a few hours
# ...

# %% [markdown]
# AMENITIES

# %%
airbnb["amenities"]
# Out:
# 0       [TV, Cable TV, Internet, Wifi, Air conditionin...
# 1       [Wifi, Wheelchair accessible, Kitchen, Free pa...
# 2       [TV, Cable TV, Wifi, Air conditioning, Pool, K...
# 3       [Air conditioning, Kitchen, Smoking allowed, D...
# 4       [TV, Cable TV, Wifi, Kitchen, Paid parking off...
#                               ...
# 5550    [Internet, Wifi, Air conditioning, Kitchen, Es...
# 5551    [TV, Wifi, Air conditioning, Kitchen, Elevator...
# 5552    [TV, Cable TV, Wifi, Kitchen, Elevator, Heatin...
# 5553    [TV, Wifi, Air conditioning, Pool, Kitchen, Fr...
# 5554    [TV, Cable TV, Internet, Wifi, Kitchen, Free p...
# Name: amenities, Length: 5555, dtype: object

# %%
Amenities=pd.DataFrame(airbnb["amenities"])
Amenities
# Out:
#                                               amenities
# 0     [TV, Cable TV, Internet, Wifi, Air conditionin...
# 1     [Wifi, Wheelchair accessible, Kitchen, Free pa...
# 2     [TV, Cable TV, Wifi, Air conditioning, Pool, K...
# 3     [Air conditioning, Kitchen, Smoking allowed, D...
# 4     [TV, Cable TV, Wifi, Kitchen, Paid parking off...
# ...                                                 ...
# 5550  [Internet, Wifi, Air conditioning, Kitchen, Es...
# 5551  [TV, Wifi, Air conditioning, Kitchen, Elevator...
# 5552  [TV, Cable TV, Wifi, Kitchen, Elevator, Heatin...
# 5553  [TV, Wifi, Air conditioning, Pool, Kitchen, Fr...
# 5554  [TV, Cable TV, Internet, Wifi, Kitchen, Free p...
#
# [5555 rows x 1 columns]

# %%
len(Amenities["amenities"][2])
# Out:
# 36

# %%
for column in Amenities["amenities"]:
    column_length=len(column)
print(column)
# Out:
# ['TV', 'Cable TV', 'Internet', 'Wifi', 'Kitchen', 'Free parking on premises', 'Elevator', 'Buzzer/wireless intercom', 'Heating', 'Family/kid friendly', 'Washer', 'Fire extinguisher', 'Essentials', 'Shampoo', 'Hangers', 'Hair dryer', 'Iron', 'Laptop friendly workspace', 'Hot water', 'Long term stays allowed', 'Host greets you']

# %%
DF=pd.DataFrame(Amenities)
# Calculate lengths of each 'amenities' list and create a new column
DF['amenities_length'] = DF['amenities'].apply(len)

# Print the DataFrame
#print(amenities)
# DF = DF.drop(columns=['DF'])
DF= pd.DataFrame(DF)
DF
# Out:
#                                               amenities  amenities_length
# 0     [TV, Cable TV, Internet, Wifi, Air conditionin...                23
# 1     [Wifi, Wheelchair accessible, Kitchen, Free pa...                15
# 2     [TV, Cable TV, Wifi, Air conditioning, Pool, K...                36
# 3     [Air conditioning, Kitchen, Smoking allowed, D...                10
# 4     [TV, Cable TV, Wifi, Kitchen, Paid parking off...                32
# ...                                                 ...               ...
# 5550  [Internet, Wifi, Air conditioning, Kitchen, Es...                11
# 5551  [TV, Wifi, Air conditioning, Kitchen, Elevator...                12
# 5552  [TV, Cable TV, Wifi, Kitchen, Elevator, Heatin...                15
# 5553  [TV, Wifi, Air conditioning, Pool, Kitchen, Fr...                15
# 5554  [TV, Cable TV, Internet, Wifi, Kitchen, Free p...                21
#
# [5555 rows x 2 columns]

# %%
DF.to_csv("amenities",index=False)

# %%
Amenities=pd.read_csv("amenities")
Amenities
# Out:
#                                               amenities  amenities_length
# 0     ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...                23
# 1     ['Wifi', 'Wheelchair accessible', 'Kitchen', '...                15
# 2     ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...                36
# 3     ['Air conditioning', 'Kitchen', 'Smoking allow...                10
# 4     ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Paid pa...                32
# ...                                                 ...               ...
# 5550  ['Internet', 'Wifi', 'Air conditioning', 'Kitc...                11
# 5551  ['TV', 'Wifi', 'Air conditioning', 'Kitchen', ...                12
# 5552  ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Elevato...                15
# 5553  ['TV', 'Wifi', 'Air conditioning', 'Pool', 'Ki...                15
# 5554  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Kitche...                21
#
# [5555 rows x 2 columns]

# %%
Amenities.isnull().sum()
# Out:
# amenities           0
# amenities_length    0
# dtype: int64

# %%
Amenities.describe()
# Out:
#        amenities_length
# count       5555.000000
# mean          21.854545
# std           11.400905
# min            1.000000
# 25%           13.000000
# 50%           20.000000
# 75%           28.000000
# max           76.000000

# %%
Q1=Amenities["amenities_length"].quantile(0.25)
Q3=Amenities["amenities_length"].quantile(0.75)

IQR=Q3-Q1
LP=Q1-(1.5*IQR)
UP=Q3+(1.5*IQR)
LP,UP
# Out:
# (-9.5, 50.5)

# %%
Amenities["amenities_length"]=Amenities["amenities_length"].clip(LP,UP)

# %%
Amenities.describe()
# Out:
#        amenities_length
# count       5555.000000
# mean          21.712781
# std           10.965277
# min            1.000000
# 25%           13.000000
# 50%           20.000000
# 75%           28.000000
# max           50.500000

# %%
Amenities.duplicated().sum()
# Out:
# 86

# %%
Amenities.drop_duplicates(inplace=True)

# %%
amenities_1=pd.DataFrame(Amenities)
amenities_1
# Out:
#                                               amenities  amenities_length
# 0     ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...              23.0
# 1     ['Wifi', 'Wheelchair accessible', 'Kitchen', '...              15.0
# 2     ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...              36.0
# 3     ['Air conditioning', 'Kitchen', 'Smoking allow...              10.0
# 4     ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Paid pa...              32.0
# ...                                                 ...               ...
# 5550  ['Internet', 'Wifi', 'Air conditioning', 'Kitc...              11.0
# 5551  ['TV', 'Wifi', 'Air conditioning', 'Kitchen', ...              12.0
# 5552  ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Elevato...              15.0
# 5553  ['TV', 'Wifi', 'Air conditioning', 'Pool', 'Ki...              15.0
# 5554  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Kitche...              21.0
#
# [5469 rows x 2 columns]

# %%
availa=pd.DataFrame(airbnb["availability"])
availa
# Out:
#                                            availability
# 0     {'availability_30': 30, 'availability_60': 31,...
# 1     {'availability_30': 0, 'availability_60': 0, '...
# 2     {'availability_30': 16, 'availability_60': 46,...
# 3     {'availability_30': 0, 'availability_60': 0, '...
# 4     {'availability_30': 28, 'availability_60': 47,...
# ...                                                 ...
# 5550  {'availability_30': 6, 'availability_60': 36, ...
# 5551  {'availability_30': 18, 'availability_60': 48,...
# 5552  {'availability_30': 28, 'availability_60': 54,...
# 5553  {'availability_30': 0, 'availability_60': 8, '...
# 5554  {'availability_30': 20, 'availability_60': 37,...
#
# [5555 rows x 1 columns]

# %%
availa["availability"][0]
# Out:
# {'availability_30': 30,
#  'availability_60': 31,
#  'availability_90': 31,
#  'availability_365': 243}

# %%
availa['availability_30'] = availa['availability'].apply(lambda x: x['availability_30'])
availa['availability_60'] = availa['availability'].apply(lambda x: x['availability_60'])
availa['availability_90'] = availa['availability'].apply(lambda x: x['availability_90'])
availa['availability_365'] = availa['availability'].apply(lambda x: x['availability_365'])
availa.drop(columns=["availability"],inplace=True)

# %%
availa
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                  30               31               31               243
# 1                   0                0                0                 0
# 2                  16               46               76               343
# 3                   0                0                0                 0
# 4                  28               47               74               239
# ...               ...              ...              ...               ...
# 5550                6               36               66               341
# 5551               18               48               78               353
# 5552               28               54               82               351
# 5553                0                8               31               258
# 5554               20               37               50               275
#
# [5555 rows x 4 columns]

# %%
availa.isnull().sum()
# Out:
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
availa.duplicated().sum()
# Out:
# 2684

# %%
availa.drop_duplicates(inplace=True)

# %%
availa.duplicated().sum()
# Out:
# 0

# %%
availa.describe()
# Out:
#        availability_30  availability_60  availability_90  availability_365
# count      2871.000000      2871.000000      2871.000000       2871.000000
# mean         11.082201        26.251480        44.379659        200.592825
# std           9.312137        17.874499        25.998366        108.597234
# min           0.000000         0.000000         0.000000          0.000000
# 25%           3.000000        11.000000        23.000000        100.500000
# 50%           9.000000        25.000000        46.000000        216.000000
# 75%          18.000000        41.000000        66.000000        300.500000
# max          30.000000        60.000000        90.000000        365.000000

# %%
Q1=availa["availability_30"].quantile(0.25)
Q3=availa["availability_30"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+(1.5*IQR)
LP=Q1-(1.5*IQR)
UP,LP
# Out:
# (40.5, -19.5)

# %%
Q1=availa["availability_60"].quantile(0.25)
Q3=availa["availability_60"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+(1.5*IQR)
LP=Q1-(1.5*IQR)
UP,LP
# Out:
# (86.0, -34.0)

# %%
Q1=availa["availability_90"].quantile(0.25)
Q3=availa["availability_90"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+(1.5*IQR)
LP=Q1-(1.5*IQR)
UP,LP
# Out:
# (130.5, -41.5)

# %%
Q1=availa["availability_365"].quantile(0.25)
Q3=availa["availability_365"].quantile(0.75)
IQR=Q3-Q1
UP=Q3+(1.5*IQR)
LP=Q1-(1.5*IQR)
UP,LP
# Out:
# (600.5, -199.5)

# %%
# no outlier cannot be using clip method
# availa["availability_365"]=availa["availability_365"].clip(LP,UP)

# %%
availability=pd.DataFrame(availa)
availability
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                  30               31               31               243
# 1                   0                0                0                 0
# 2                  16               46               76               343
# 4                  28               47               74               239
# 6                  28               58               88               363
# ...               ...              ...              ...               ...
# 5547                7               37               67                87
# 5548                2               11               15               154
# 5552               28               54               82               351
# 5553                0                8               31               258
# 5554               20               37               50               275
#
# [2871 rows x 4 columns]

# %%
# availability.to_csv("availability",index=False)

# %%
# Availability=pd.read_csv("availability")
Availability=pd.DataFrame(availability)
Availability
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                  30               31               31               243
# 1                   0                0                0                 0
# 2                  16               46               76               343
# 4                  28               47               74               239
# 6                  28               58               88               363
# ...               ...              ...              ...               ...
# 5547                7               37               67                87
# 5548                2               11               15               154
# 5552               28               54               82               351
# 5553                0                8               31               258
# 5554               20               37               50               275
#
# [2871 rows x 4 columns]

# %%
review=pd.DataFrame(airbnb["review_scores"])
review
# Out:
#                                           review_scores
# 0     {'review_scores_accuracy': 9, 'review_scores_c...
# 1                                                    {}
# 2     {'review_scores_accuracy': 9, 'review_scores_c...
# 3     {'review_scores_accuracy': 10, 'review_scores_...
# 4     {'review_scores_accuracy': 9, 'review_scores_c...
# ...                                                 ...
# 5550                                                 {}
# 5551  {'review_scores_accuracy': 10, 'review_scores_...
# 5552  {'review_scores_accuracy': 9, 'review_scores_c...
# 5553  {'review_scores_accuracy': 10, 'review_scores_...
# 5554  {'review_scores_accuracy': 10, 'review_scores_...
#
# [5555 rows x 1 columns]

# %%
review["review_scores"].values[0]
# Out:
# {'review_scores_accuracy': 9,
#  'review_scores_cleanliness': 10,
#  'review_scores_checkin': 10,
#  'review_scores_communication': 8,
#  'review_scores_location': 9,
#  'review_scores_value': 9,
#  'review_scores_rating': 88}

# %%
# Extract review scores from nested 'review_scores' dictionary
review['review_scores_accuracy'] = review['review_scores'].apply(lambda x: x.get('review_scores_accuracy',0))
review['review_scores_cleanliness'] = review['review_scores'].apply(lambda x: x.get('review_scores_cleanliness',0))
review['review_scores_checkin'] = review['review_scores'].apply(lambda x: x.get('review_scores_checkin',0))
review['review_scores_communication'] = review['review_scores'].apply(lambda x: x.get('review_scores_communication',0))
review['review_scores_location'] = review['review_scores'].apply(lambda x: x.get('review_scores_location',0))
review['review_scores_value'] = review['review_scores'].apply(lambda x: x.get('review_scores_value',0))
review['review_scores_rating'] = review['review_scores'].apply(lambda x: x.get('review_scores_rating',0))

# Drop the original 'review_scores' column if not needed
review.drop(columns=['review_scores'], inplace=True)

# %%
review
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                          9                         10
# 1                          0                          0
# 2                          9                          8
# 3                         10                         10
# 4                          9                          9
# ...                      ...                        ...
# 5550                       0                          0
# 5551                      10                          9
# 5552                       9                          9
# 5553                      10                          9
# 5554                      10                         10
#
#       review_scores_checkin  review_scores_communication  \
# 0                        10                            8
# 1                         0                            0
# 2                         9                            9
# 3                        10                           10
# ...

# %%
review.isnull().sum()
# Out:
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# review_scores_rating           0
# dtype: int64

# %%
review.dtypes
# Out:
# review_scores_accuracy         int64
# review_scores_cleanliness      int64
# review_scores_checkin          int64
# review_scores_communication    int64
# review_scores_location         int64
# review_scores_value            int64
# review_scores_rating           int64
# dtype: object

# %%
review.duplicated().sum()
# Out:
# 4391

# %%
review.drop_duplicates(inplace=True)

# %%
review.describe()
# Out:
#        review_scores_accuracy  review_scores_cleanliness  \
# count             1164.000000                1164.000000
# mean                 8.898625                   8.526632
# std                  1.398943                   1.538884
# min                  0.000000                   0.000000
# 25%                  9.000000                   8.000000
# 50%                  9.000000                   9.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            1164.000000                  1164.000000
# mean                9.184708                     9.169244
# std                 1.268471                     1.279395
# min                 0.000000                     0.000000
# 25%                 9.000000                     9.000000
# 50%                10.000000                     9.000000
# ...

# %%
review["review_scores_accuracy"].value_counts()
# Out:
# review_scores_accuracy
# 9     470
# 10    414
# 8     193
# 6      32
# 7      24
# 4      14
# 2      10
# 0       5
# 3       1
# 5       1
# Name: count, dtype: int64

# %%
# review.to_csv("review",index=False)

# %%
# review_score=pd.read_csv("review")
review_score=pd.DataFrame(review)
review_score
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                          9                         10
# 1                          0                          0
# 2                          9                          8
# 3                         10                         10
# 4                          9                          9
# ...                      ...                        ...
# 5514                       6                          6
# 5543                       6                          8
# 5546                      10                         10
# 5549                       8                          9
# 5551                      10                          9
#
#       review_scores_checkin  review_scores_communication  \
# 0                        10                            8
# 1                         0                            0
# 2                         9                            9
# 3                        10                           10
# ...

# %%
Airbnb
# Out:
#                                                    name property_type  \
# 0                                     Deluxe Loft Suite     Apartment
# 1                          Horto flat with small garden     Apartment
# 2                      Ocean View Waikiki Marina w/prkg   Condominium
# 3                    Soho Cozy, Spacious and Convenient     Apartment
# 4                               Ribeira Charming Duplex         House
# ...                                                 ...           ...
# 5550             Cozy Private Room near Olympic MTR (A)     Apartment
# 5551                Quarry Bay fully furnished studio C     Apartment
# 5552                   StayIN Oporto Música - Apartment     Apartment
# 5553  Just Steps from the Ocean at Premier Platinum ...     Townhouse
# 5554                 Central, Modern, University, Metro     Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# ...

# %%
address
# Out:
#               street                      suburb       government_area  \
# 0           Brooklyn                  Greenpoint            Greenpoint
# 1     Rio de Janeiro             Jardim Botânico       Jardim Botânico
# 2           Honolulu                       Oʻahu  Primary Urban Center
# 3          Hong Kong  Central & Western District     Central & Western
# 4              Porto                         NaN             Cedofeita
# ...              ...                         ...                   ...
# 5550       Hong Kong               Yau Tsim Mong         Yau Tsim Mong
# 5551       Hong Kong                  Quarry Bay               Eastern
# 5552           Porto                         NaN             Cedofeita
# 5553         Lahaina                     Lahaina               Lahaina
# 5554           Porto                         NaN             Cedofeita
#
#               market        country country_code   type   Latitude  Longitude  \
# ...

# %%
host
# Out:
#                                         host_url       host_name  \
# 0     https://www.airbnb.com/users/show/47554473             Mae
# 1      https://www.airbnb.com/users/show/1282196           Ynaie
# 2      https://www.airbnb.com/users/show/5448114           David
# 3     https://www.airbnb.com/users/show/51624384        Giovanni
# 4     https://www.airbnb.com/users/show/51399391     Ana&Gonçalo
# ...                                          ...             ...
# 5547  https://www.airbnb.com/users/show/50141940           Paola
# 5548  https://www.airbnb.com/users/show/40540485          Miguel
# 5551  https://www.airbnb.com/users/show/31386255             Cat
# 5552   https://www.airbnb.com/users/show/2296185          Manuel
# 5554   https://www.airbnb.com/users/show/2068687  Daniel & Maria
#
#                                         host_location  host_response_time  \
# 0                                                  US  within a few hours
# ...

# %%
amenities_1
# Out:
#                                               amenities  amenities_length
# 0     ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...              23.0
# 1     ['Wifi', 'Wheelchair accessible', 'Kitchen', '...              15.0
# 2     ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...              36.0
# 3     ['Air conditioning', 'Kitchen', 'Smoking allow...              10.0
# 4     ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Paid pa...              32.0
# ...                                                 ...               ...
# 5550  ['Internet', 'Wifi', 'Air conditioning', 'Kitc...              11.0
# 5551  ['TV', 'Wifi', 'Air conditioning', 'Kitchen', ...              12.0
# 5552  ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Elevato...              15.0
# 5553  ['TV', 'Wifi', 'Air conditioning', 'Pool', 'Ki...              15.0
# 5554  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Kitche...              21.0
#
# [5469 rows x 2 columns]

# %%
Availability
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                  30               31               31               243
# 1                   0                0                0                 0
# 2                  16               46               76               343
# 4                  28               47               74               239
# 6                  28               58               88               363
# ...               ...              ...              ...               ...
# 5547                7               37               67                87
# 5548                2               11               15               154
# 5552               28               54               82               351
# 5553                0                8               31               258
# 5554               20               37               50               275
#
# [2871 rows x 4 columns]

# %%
review_score
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                          9                         10
# 1                          0                          0
# 2                          9                          8
# 3                         10                         10
# 4                          9                          9
# ...                      ...                        ...
# 5514                       6                          6
# 5543                       6                          8
# 5546                      10                         10
# 5549                       8                          9
# 5551                      10                          9
#
#       review_scores_checkin  review_scores_communication  \
# 0                        10                            8
# 1                         0                            0
# 2                         9                            9
# 3                        10                           10
# ...

# %%
Tc=Airbnb.groupby(["property_type"])["price"].sum().sort_values(ascending=False).nlargest(10).to_frame()
Tc=Tc.reset_index()
Tc

# %%
pd.set_option('display.max_columns', 500)

# %%
airbnbs=pd.concat([Airbnb,host,address,Availability,amenities_1,review_score],axis=1)
airbnbs

# %%
airbnbs.isnull().sum()

# %%
catagorical_column=["host_url","host_name","host_location","host_response_time","host_is_superhost","host_has_profile_pic","host_identity_verified","street","suburb","market","amenities"]
for column in catagorical_column:
    airbnbs[column].fillna(airbnbs[column].mode()[0],inplace=True)
#fill missing values in numerical column with mean, meidean
numerical_column=["host_response_rate","host_listings_count","host_total_listings_count","host_verifications","host_verifications","availability_30","availability_60","availability_90","availability_365","amenities_length"]
for column in numerical_column:
    airbnbs[column].fillna(airbnbs[column].mean(),inplace=True)

# %%
airbnbs.drop(columns=['review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','review_scores_rating'],inplace=True)

# %%
airbnbs.isnull().sum()

# %%
airbnbs.duplicated().sum()

# %%
airbnbs

# %%
Airbnb_data=pd.DataFrame(airbnbs)
# Airbnb_data

# %%
Airbnb_data.to_csv("Airbnb_data.csv",index=False)
Airbnb_data=pd.read_csv("Airbnb_data.csv")

# %%
Airbnb_data
